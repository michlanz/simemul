# %% [markdown]
# # TODO
# - il find best, evaluation e le altre cose sono imputtanatissime e non si capisce niente. è tutto troppo segmentato e richiede troppi miei passaggi espliciti, quando io vorrei una pipeline elegante e senza menate eccessive
# - le immagini heatmap combinate devono avere gli assi espliciti e non la legenda a parte
# - i cut di pareto devono essere salvate singolarmente/in verticale. all'immagine più a sinistra non si vede l'asse Y
# - serve più legenda nelle grid di pareto
# - forse dovremmo ripensare al caricamento dell'anova solo se mettiamo l'anova, anche se aveva dato problemi. gli altri moduli non pesano così tanto
# - sono molto infastidita dal fatto che le mie adattive non funzionino e non saprei come fare per avere risultati migliori
# - ci sono 34 errori per nessun motivo
# - si sarebbero potute pensare le campagne in modo più intelligente
#
# - non mettere la normale ma magari una lognormale e con CV più alto
